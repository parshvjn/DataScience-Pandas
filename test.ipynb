# %%
import pandas as pd

# %%
deaths_data = pd.read_csv("WHO-COVID-19-global-table-data.csv")

# %%
vaccination_data = pd.read_csv("vaccination-data.csv")

# %%
deaths_data
# Out:
#                                                   Name  WHO Region  \
# Global                                             NaN   771549718
# United States of America                      Americas   103436829
# China                                  Western Pacific    99316932
# India                                  South-East Asia    45001052
# France                                          Europe    38997490
# ...                                                ...         ...
# Tokelau                                Western Pacific          80
# Holy See                                        Europe          26
# Pitcairn Islands                       Western Pacific           4
# Democratic People's Republic of Korea  South-East Asia           0
# Turkmenistan                                    Europe           0
#
#                                        Cases - cumulative total  \
# Global                                               9898.59161
# ...

# %%
deaths_data["Deaths - cumulative total"].max()
# Out:
# 672.404

# %%
deaths_data.columns
# Out:
# Index(['Name', 'WHO Region', 'Cases - cumulative total',
#        'Cases - cumulative total per 100000 population',
#        'Cases - newly reported in last 7 days',
#        'Cases - newly reported in last 7 days per 100000 population',
#        'Cases - newly reported in last 24 hours', 'Deaths - cumulative total',
#        'Deaths - cumulative total per 100000 population',
#        'Deaths - newly reported in last 7 days',
#        'Deaths - newly reported in last 7 days per 100000 population',
#        'Deaths - newly reported in last 24 hours'],
#       dtype='object')

# %%
vaccination_data.describe()
# Out:
#        TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# count        2.280000e+02                   2.290000e+02
# mean         5.935731e+07                   2.444375e+07
# std          2.839890e+08                   1.138834e+08
# min          1.170000e+02                   0.000000e+00
# 25%          4.736552e+05                   1.923710e+05
# 50%          4.749752e+06                   2.740227e+06
# 75%          2.336545e+07                   1.088471e+07
# max          3.516881e+09                   1.318027e+09
#
#        TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# count                 224.000000                            229.000000
# mean                  157.521536                             64.019803
# std                    84.387226                             25.280910
# min                     0.348000                              0.000000
# 25%                    87.040000                             45.654000
# ...

# %%
vaccination_data.iloc[45:54]
# Out:
#                              COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 45                         Lithuania  LTU       EURO   REPORTING   2023-10-01
# 46                            Malawi  MWI       AFRO   REPORTING   2023-09-24
# 47                          Maldives  MDV      SEARO   REPORTING   2023-05-25
# 48                             Malta  MLT       EURO   REPORTING   2023-09-03
# 49                       Netherlands  NLD       EURO   REPORTING   2023-10-01
# 50                             Niger  NER       AFRO   REPORTING   2023-07-30
# 51                           Romania  ROU       EURO   REPORTING   2023-09-10
# 52  Saint Vincent and the Grenadines  VCT       AMRO   REPORTING   2023-06-02
# 53                          Slovakia  SVK       EURO   REPORTING   2023-10-01
#
#     TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 45           4532726.0                        1956489
# 46           8503954.0                        5433538
# ...

# %%
deaths_data.loc["Romania"]
# Out:
# Name                                                               Europe
# WHO Region                                                        3485792
# Cases - cumulative total                                        18034.152
# Cases - cumulative total per 100000 population                          0
# Cases - newly reported in last 7 days                                 0.0
# Cases - newly reported in last 7 days per 100000 population             0
# Cases - newly reported in last 24 hours                             68455
# Deaths - cumulative total                                          354.16
# Deaths - cumulative total per 100000 population                         0
# Deaths - newly reported in last 7 days                                0.0
# Deaths - newly reported in last 7 days per 100000 population            0
# Deaths - newly reported in last 24 hours                              NaN
# Name: Romania, dtype: object

# %%
deaths_data[deaths_data["Name"].isin(vaccination_data.COUNTRY)]
# Out:
# Empty DataFrame
# Columns: [Name, WHO Region, Cases - cumulative total, Cases - cumulative total per 100000 population, Cases - newly reported in last 7 days, Cases - newly reported in last 7 days per 100000 population, Cases - newly reported in last 24 hours, Deaths - cumulative total, Deaths - cumulative total per 100000 population, Deaths - newly reported in last 7 days, Deaths - newly reported in last 7 days per 100000 population, Deaths - newly reported in last 24 hours]
# Index: []

# %%
deaths_data[deaths_data["Name"] == "Europe"]
# Out:
#                       Name  WHO Region  Cases - cumulative total  \
# France              Europe    38997490                 59959.831
# Germany             Europe    38437756                 46217.718
# Italy               Europe    26202253                 43932.930
# The United Kingdom  Europe    24789488                 36516.346
# Russian Federation  Europe    23098734                 15828.156
# ...                    ...         ...                       ...
# Tajikistan          Europe       17786                   186.482
# Monaco              Europe       17072                 43502.191
# Greenland           Europe       11971                 21086.099
# Holy See            Europe          26                  3213.844
# Turkmenistan        Europe           0                     0.000
#
#                     Cases - cumulative total per 100000 population  \
# France                                                           0
# ...
